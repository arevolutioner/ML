# %% [markdown]
# ### Introduction to Matplotlib

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
plt.style.use('seaborn')

# %%
plt.plot()
# Out:
# []

# %%
plt.plot();

# %%
plt.plot([1,2,3,4]);

# %%
x = [1,2,3,4]
y = [11,22,33,44]
plt.plot(x,y);

# %%
# 1st method
fig = plt.figure() #creates a figure
ax = fig.add_subplot()
plt.show()

# %%
# 2nd method 
fig = plt.figure() #create figure
ax = fig.add_axes([1,1,1,1])
ax.plot(x,y) #add some data
plt.show()

# %% [markdown]
# ### Object oriented API

# %%
# 3rd method (RECOMENDED)
fig, ax = plt.subplots()
ax.plot(x,y); #add some data
type(fig), type(ax)
# Out:
# (matplotlib.figure.Figure, matplotlib.axes._subplots.AxesSubplot)

# %% [markdown]
# ## Matplotlib example workflow

# %%
# 0. import matplotlib and get it ready for plotting Jupyter
# %matplotlib inline
import matplotlib.pyplot as plt

# 1. Prepare data
x = [1,2,3,4]
y = [11,22,33,44]

# 2. Setup plot
fig, ax = plt.subplots(figsize = (10, 10))

# 3. Plot data
ax.plot(x,y)

# 4. Customize plot
ax.set(title = 'Simple plot',
      xlabel = 'x-axis',
      ylabel = 'y-axis')
# 5. Save and show (you save the whole figure)
fig.savefig("sample-plot.png")

# %% [markdown]
# # Making figures with NumPy arrays
#
# ### We want:
#     * Line plot;
#     * Scatter plot;
#     * Bar plot;
#     * Histogram;
#     * Subplots;

# %%
# cvreate some data
x = np.linspace(0,10,100)
x[:10]
# Out:
# array([0.        , 0.1010101 , 0.2020202 , 0.3030303 , 0.4040404 ,
#        0.50505051, 0.60606061, 0.70707071, 0.80808081, 0.90909091])

# %%
# Plot the data and create a line plot
fig, ax = plt.subplots()
ax.plot(x, x**2);

# %%
# Make a scatter with the same data
fig, ax = plt.subplots()
ax.scatter(x, np.exp(x));

# %%
fig, ax = plt.subplots()
ax.scatter(x, np.sin(x));

# %%
# Make a bar plot with a dictionary data
nut_butter_prices = {
    'Almond butter': 10,
    'Peanut butter': 6,
    'Cashew butter': 15}
fig, ax = plt.subplots()
ax.bar(nut_butter_prices.keys(),nut_butter_prices.values());
ax.set(title = "Nut Butter Store", 
       ylabel= "Price ($)");

# %%
fig, ax = plt.subplots()
ax.barh(list(nut_butter_prices.keys()), 
        list(nut_butter_prices.values()));

# %%
# Make some data
x = np.random.randn(100)
x
# Out:
# array([ 0.93888866, -0.33236761, -0.47069918,  0.60834662, -0.67592465,
#        -0.82563431,  1.16562135,  1.35020037, -1.36860478, -1.23799065,
#        -1.02836966, -1.15325016,  2.01461778, -1.03540456,  1.56544249,
#         1.58106679, -0.8027976 , -0.7954275 , -0.30097426, -0.00962773,
#        -0.08882683,  1.56631148, -1.79897262, -0.04712588,  0.20316153,
#         0.76400834, -0.70681454, -1.10815664, -0.65591015, -1.25724997,
#         0.93227466, -2.34828267,  0.10240629,  1.31278549,  0.10604084,
#         0.77761853,  0.11802026,  0.9352888 ,  0.90881382,  1.05111613,
#        -1.24388125,  0.0135317 ,  0.15276303,  2.19077151,  0.5779934 ,
#        -1.70043538,  1.18747997,  0.69724907,  0.55127782, -0.31152796,
#         2.56954651, -1.50642649, -2.78998879, -3.85574209, -1.14706103,
#         1.67863933,  0.02490977, -0.39770333,  0.88620568, -0.65231435,
#        -0.37020079, -1.68606204,  0.13930449,  0.45646828,  0.95390555,
# ...

# %%
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# ## Two options for subplots

# %%
# Subplot option 1
fig, ((ax1,ax2), (ax3, ax4)) = plt.subplots(nrows=2,
                                           ncols=2,
                                           figsize = (10,5))
# Plot to each different axis
ax1.plot(x,x/2);
ax2.scatter(np.random.random(10), np.random.random(10));
ax3.bar(nut_butter_prices.keys(), nut_butter_prices.values());
ax4.hist(np.random.randn(1000));

# %%
# Subplots option 2
fig, ax = plt.subplots(nrows=2,
                      ncols=2,
                      figsize = (10,5))
# Plot to each different index
ax[0,0].plot(x, x/2);
ax[0,1].scatter(np.random.random(10), np.random.random(10));
ax[1,0].bar(nut_butter_prices.keys(), nut_butter_prices.values()); 
ax[1,1].hist(np.random.randn(1000));

# %% [markdown]
# ## Plotting from pandas DataFRAME

# %%
# Make a dataframe
car_sales = pd.read_csv('carsales.csv')
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
In [3]: ts = pd.Series(np.random.randn(1000),
   ...:                index=pd.date_range('1/1/2000', periods=1000))
   ...: 

In [4]: ts = ts.cumsum()

In [5]: ts.plot();
Out[5]: <matplotlib.axes._subplots.AxesSubplot at 0x7f9d87b52df0>
# Out:
#   File "<ipython-input-241-43a16ef1e1cd>", line 8
#     Out[5]: <matplotlib.axes._subplots.AxesSubplot at 0x7f9d87b52df0>
#             ^
# SyntaxError: invalid syntax

# %%
ts = pd.Series(np.random.randn(1000),
              index=pd.date_range('1/1/2020', periods=1000))
ts =ts.cumsum()
ts.plot();

# %%
car_sales["Price"] = car_sales["Price"].str.replace('[\$\,\.]','')
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# remove last two zeros
car_sales["Price"] = car_sales["Price"].str[:-2]
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
car_sales["Sale Date"] = pd.date_range("1/1/2020", periods=len(car_sales))
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2020-01-01
# 1   Honda    Red          87899      4   5000 2020-01-02
# 2  Toyota   Blue          32549      3   7000 2020-01-03
# 3     BMW  Black          11179      5  22000 2020-01-04
# 4  Nissan  White         213095      4   3500 2020-01-05
# 5  Toyota  Green          99213      4   4500 2020-01-06
# 6   Honda   Blue          45698      4   7500 2020-01-07
# 7   Honda   Blue          54738      4   7000 2020-01-08
# 8  Toyota  White          60000      4   6250 2020-01-09
# 9  Nissan  White          31600      4   9700 2020-01-10

# %%
car_sales["Total Sales"] = car_sales["Price"].astype(int).cumsum()
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
# Let's plot the total sales
car_sales.plot(x="Sale Date", y="Total Sales")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
# Convert Price column into int
car_sales["Price"] = car_sales["Price"].astype(int)

# %%
car_sales.plot(x="Odometer (KM)", y= "Price", kind="scatter")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500
# 5  Toyota  Green          99213      4   4500 2020-01-06        46000
# 6   Honda   Blue          45698      4   7500 2020-01-07        53500
# 7   Honda   Blue          54738      4   7000 2020-01-08        60500
# 8  Toyota  White          60000      4   6250 2020-01-09        66750
# 9  Nissan  White          31600      4   9700 2020-01-10        76450

# %%
car_sales.plot(x="Make", y="Odometer (KM)", kind="bar");

# %%
car_sales["Odometer (KM)"].plot.hist();

# %%
car_sales["Odometer (KM)"].plot(kind="hist");

# %%
car_sales["Odometer (KM)"].plot.hist(bins=20);

# %%
heart_disease = pd.read_csv("heart-disease.csv")
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
# Create a histogram of age
heart_disease["age"].plot.hist();

# %%
 # When plotting something simpole it is ok to use pyplot method
# When plotting something more advance use OO method 
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease["age"]>50]
over_50.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
# 5   57    1   0       140   192    0        1      148      0      0.4      1
# 6   56    0   1       140   294    0        0      153      0      1.3      1
#
#    ca  thal  target
# 0   0     1       1
# 3   0     2       1
# 4   0     2       1
# 5   0     1       1
# 6   0     2       1

# %%
# PyPlot method AKA plotting directly from the data frame Pandas
over_50.plot(
kind = 'scatter',
x='age',
y='chol',
c='target');

# %%
# OO method=matplotlib miced with pyplot method
fig, ax=plt.subplots(figsize=(10,6))
over_50.plot(
kind = 'scatter',
x='age',
y='chol',
c='target',
ax=ax);
ax.set_xlim([45,100]);

# %%
# Object Oriented method from scratch
fig, ax =plt.subplots(figsize=(10,6))
#Plot the data
scatter = ax.scatter(x=over_50['age'],
y=over_50['chol'],
c=over_50['target']);
# Customize the plot
ax.set(title='Heart Disease and Cholesterol Levels',
      xlabel="Age",
      ylabel="Cholesterol");
# Add a legend 
ax.legend(*scatter.legend_elements(), title="target");
# Add a horizontal line
ax.axhline(over_50["chol"].mean(), linestyle='--');

# %%
# Subplot of chol, age, thalach
fig, (ax0, ax1)=plt.subplots(nrows=2,ncols=1, figsize=(10, 10));
# Add data to ax()
scatter = ax0.scatter(x=over_50['age'],y=over_50['chol'],
                       c=over_50['target']);
# Customize ax0
ax0.set(title="Heart Disease adn Cholesterol Levels",
        xlabel="Age",
        ylabel="Cholesterol");
# Add a legend 
ax0.legend(*scatter.legend_elements(), title="target");
# Add a horizontal line
ax0.axhline(over_50["chol"].mean(), linestyle='--');
# Add data to ax1
scatter = ax1.scatter(x=over_50['age'],y=over_50['thalach'],
                       c=over_50['target']);
# Customize ax0
ax1.set(title="Heart Disease and Max Heart Rate",
        xlabel="Age",
        ylabel="Max Heart Rate");
# Add a legend 
ax1.legend(*scatter.legend_elements(), title="target");
# Add a horizontal line
ax1.axhline(over_50["thalach"].mean(), linestyle='--');

# %% [markdown]
# ## CUstomize the style

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
car_sales["Price"].plot();

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total Sales
# 0  Toyota  White         150043      4   4000 2020-01-01         4000
# 1   Honda    Red          87899      4   5000 2020-01-02         9000
# 2  Toyota   Blue          32549      3   7000 2020-01-03        16000
# 3     BMW  Black          11179      5  22000 2020-01-04        38000
# 4  Nissan  White         213095      4   3500 2020-01-05        41500

# %%
plt.style.use('seaborn-whitegrid')
car_sales["Price"].plot();

# %%
plt.style.use('seaborn')
car_sales["Price"].plot();

# %%
car_sales.plot(x="Odometer (KM)", y="Price", kind="scatter");

# %%
# Create some data
x=np.random.randn(10,4)
x
# Out:
# array([[ 1.49068514,  0.79952985, -0.08036699,  0.13572971],
#        [-0.8671075 ,  2.19827866,  0.53607468, -0.99369226],
#        [-1.09797501, -0.80641211,  0.79895015,  0.38304467],
#        [ 0.97315386,  0.89283438,  3.32072504,  0.28662235],
#        [ 1.21944835,  0.18210326, -2.65749125, -0.35035682],
#        [ 0.7497021 ,  0.31516246, -0.88555288, -0.3997316 ],
#        [ 0.23718834, -2.0226969 , -0.84916884, -0.50913637],
#        [ 0.10548138,  1.28683456,  2.13814435, -1.83124072],
#        [ 0.66360057, -0.03842162,  0.78424905, -0.22100071],
#        [-0.01686871,  1.24250321,  2.28670987, -0.9968916 ]])

# %%
df = pd.DataFrame(x, columns=['a','b','c','d'])
df
# Out:
#           a         b         c         d
# 0  1.490685  0.799530 -0.080367  0.135730
# 1 -0.867107  2.198279  0.536075 -0.993692
# 2 -1.097975 -0.806412  0.798950  0.383045
# 3  0.973154  0.892834  3.320725  0.286622
# 4  1.219448  0.182103 -2.657491 -0.350357
# 5  0.749702  0.315162 -0.885553 -0.399732
# 6  0.237188 -2.022697 -0.849169 -0.509136
# 7  0.105481  1.286835  2.138144 -1.831241
# 8  0.663601 -0.038422  0.784249 -0.221001
# 9 -0.016869  1.242503  2.286710 -0.996892

# %%
ax=df.plot(kind='bar')
ax;

# %%
# Customize our plot
ax=df.plot(kind='bar')
ax.set(title="Random bar Graph form DataFrame",
      xlabel ="Row number",
      ylabel='Random number')
ax.legend().set_visible(True)

# %%
# Object Oriented method from scratch
fig, ax =plt.subplots(figsize=(10,6))
#Plot the data
scatter = ax.scatter(x=over_50['age'],
y=over_50['chol'],
c=over_50['target'],
cmap='magma'); #this changes the colour schema
# Customize the plot
ax.set(title='Heart Disease and Cholesterol Levels',
      xlabel="Age",
      ylabel="Cholesterol");
# Add a legend 
ax.legend(*scatter.legend_elements(), title="target");
# Add a horizontal line
ax.axhline(over_50["chol"].mean(), linestyle='--');
